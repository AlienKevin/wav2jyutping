# %% [markdown]
# # Fine-Tune Whisper For Multilingual ASR with 🤗 Transformers

# %% [markdown]
# In this Colab, we present a step-by-step guide on how to fine-tune Whisper
# for any multilingual ASR dataset using Hugging Face 🤗 Transformers. This is a
# more "hands-on" version of the accompanying [blog post](https://huggingface.co/blog/fine-tune-whisper).
# For a more in-depth explanation of Whisper, the Common Voice dataset and the theory behind fine-tuning, the reader is advised to refer to the blog post.

# %% [markdown]
# ## Introduction

# %% [markdown]
# Whisper is a pre-trained model for automatic speech recognition (ASR)
# published in [September 2022](https://openai.com/blog/whisper/) by the authors
# Alec Radford et al. from OpenAI. Unlike many of its predecessors, such as
# [Wav2Vec 2.0](https://arxiv.org/abs/2006.11477), which are pre-trained
# on un-labelled audio data, Whisper is pre-trained on a vast quantity of
# **labelled** audio-transcription data, 680,000 hours to be precise.
# This is an order of magnitude more data than the un-labelled audio data used
# to train Wav2Vec 2.0 (60,000 hours). What is more, 117,000 hours of this
# pre-training data is multilingual ASR data. This results in checkpoints
# that can be applied to over 96 languages, many of which are considered
# _low-resource_.
#
# When scaled to 680,000 hours of labelled pre-training data, Whisper models
# demonstrate a strong ability to generalise to many datasets and domains.
# The pre-trained checkpoints achieve competitive results to state-of-the-art
# ASR systems, with near 3% word error rate (WER) on the test-clean subset of
# LibriSpeech ASR and a new state-of-the-art on TED-LIUM with 4.7% WER (_c.f._
# Table 8 of the [Whisper paper](https://cdn.openai.com/papers/whisper.pdf)).
# The extensive multilingual ASR knowledge acquired by Whisper during pre-training
# can be leveraged for other low-resource languages; through fine-tuning, the
# pre-trained checkpoints can be adapted for specific datasets and languages
# to further improve upon these results. We'll show just how Whisper can be fine-tuned
# for low-resource languages in this Colab.

# %% [markdown]
# <figure>
# <img src="https://raw.githubusercontent.com/sanchit-gandhi/notebooks/main/whisper_architecture.svg" alt="Trulli" style="width:100%">
# <figcaption align = "center"><b>Figure 1:</b> Whisper model. The architecture
# follows the standard Transformer-based encoder-decoder model. A
# log-Mel spectrogram is input to the encoder. The last encoder
# hidden states are input to the decoder via cross-attention mechanisms. The
# decoder autoregressively predicts text tokens, jointly conditional on the
# encoder hidden states and previously predicted tokens. Figure source:
# <a href="https://openai.com/blog/whisper/">OpenAI Whisper Blog</a>.</figcaption>
# </figure>

# %% [markdown]
# The Whisper checkpoints come in five configurations of varying model sizes.
# The smallest four are trained on either English-only or multilingual data.
# The largest checkpoint is multilingual only. All nine of the pre-trained checkpoints
# are available on the [Hugging Face Hub](https://huggingface.co/models?search=openai/whisper). The
# checkpoints are summarised in the following table with links to the models on the Hub:
#
# | Size   | Layers | Width | Heads | Parameters | English-only                                         | Multilingual                                      |
# |--------|--------|-------|-------|------------|------------------------------------------------------|---------------------------------------------------|
# | tiny   | 4      | 384   | 6     | 39 M       | [✓](https://huggingface.co/openai/whisper-base.en)   | [✓](https://huggingface.co/openai/whisper-base.)  |
# | base   | 6      | 512   | 8     | 74 M       | [✓](https://huggingface.co/openai/whisper-base.en)   | [✓](https://huggingface.co/openai/whisper-base)   |
# | small  | 12     | 768   | 12    | 244 M      | [✓](https://huggingface.co/openai/whisper-small.en)  | [✓](https://huggingface.co/openai/whisper-small)  |
# | medium | 24     | 1024  | 16    | 769 M      | [✓](https://huggingface.co/openai/whisper-medium.en) | [✓](https://huggingface.co/openai/whisper-medium) |
# | large  | 32     | 1280  | 20    | 1550 M     | x                                                    | [✓](https://huggingface.co/openai/whisper-large)  |
#
# For demonstration purposes, we'll fine-tune the multilingual version of the
# [`"small"`](https://huggingface.co/openai/whisper-small) checkpoint with 244M params (~= 1GB).
# As for our data, we'll train and evaluate our system on a low-resource language
# taken from the [Common Voice](https://huggingface.co/datasets/mozilla-foundation/common_voice_11_0)
# dataset. We'll show that with as little as 8 hours of fine-tuning data, we can achieve
# strong performance in this language.

# %% [markdown]
# ------------------------------------------------------------------------
#
# \\({}^1\\) The name Whisper follows from the acronym “WSPSR”, which stands for “Web-scale Supervised Pre-training for Speech Recognition”.

# %% [markdown]
# ## Prepare Environment

# %% [markdown]
# First of all, let's try to secure a decent GPU for our Colab! Unfortunately, it's becoming much harder to get access to a good GPU with the free version of Google Colab. However, with Google Colab Pro one should have no issues in being allocated a V100 or P100 GPU.
#
# To get a GPU, click _Runtime_ -> _Change runtime type_, then change _Hardware accelerator_ from _None_ to _GPU_.

# %% [markdown]
# We can verify that we've been assigned a GPU and view its specifications:

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

# %% [markdown]
# We'll employ several popular Python packages to fine-tune the Whisper model.
# We'll use `datasets` to download and prepare our training data and
# `transformers` to load and train our Whisper model. We'll also require
# the `soundfile` package to pre-process audio files, `evaluate` and `jiwer` to
# assess the performance of our model. Finally, we'll
# use `gradio` to build a flashy demo of our fine-tuned model.

# %%
# !pip install datasets==2.14.5
# !pip install git+https://github.com/huggingface/transformers
# !pip install librosa
# !pip install evaluate==0.4.0
# !pip install jiwer
# !pip install gradio
# Out:
# Requirement already satisfied: datasets==2.14.5 in /Users/kevin/miniconda3/lib/python3.11/site-packages (2.14.5)
# Requirement already satisfied: numpy>=1.17 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from datasets==2.14.5) (1.24.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from datasets==2.14.5) (13.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from datasets==2.14.5) (0.3.7)
# Requirement already satisfied: pandas in /Users/kevin/miniconda3/lib/python3.11/site-packages (from datasets==2.14.5) (2.1.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from datasets==2.14.5) (2.29.0)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from datasets==2.14.5) (4.65.0)
# Requirement already satisfied: xxhash in /Users/kevin/miniconda3/lib/python3.11/site-packages (from datasets==2.14.5) (3.3.0)
# Requirement already satisfied: multiprocess in /Users/kevin/miniconda3/lib/python3.11/site-packages (from datasets==2.14.5) (0.70.15)
# Requirement already satisfied: fsspec[http]<2023.9.0,>=2023.1.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from datasets==2.14.5) (2023.6.0)
# Requirement already satisfied: aiohttp in /Users/kevin/miniconda3/lib/python3.11/site-packages (from datasets==2.14.5) (3.8.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from datasets==2.14.5) (0.16.4)
# Requirement already satisfied: packaging in /Users/kevin/miniconda3/lib/python3.11/site-packages (from datasets==2.14.5) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from datasets==2.14.5) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from aiohttp->datasets==2.14.5) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from aiohttp->datasets==2.14.5) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from aiohttp->datasets==2.14.5) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from aiohttp->datasets==2.14.5) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from aiohttp->datasets==2.14.5) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from aiohttp->datasets==2.14.5) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from aiohttp->datasets==2.14.5) (1.3.1)
# Requirement already satisfied: filelock in /Users/kevin/miniconda3/lib/python3.11/site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets==2.14.5) (3.12.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets==2.14.5) (4.7.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from requests>=2.19.0->datasets==2.14.5) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from requests>=2.19.0->datasets==2.14.5) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from requests>=2.19.0->datasets==2.14.5) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from pandas->datasets==2.14.5) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from pandas->datasets==2.14.5) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from pandas->datasets==2.14.5) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets==2.14.5) (1.16.0)
# Collecting git+https://github.com/huggingface/transformers
#   Cloning https://github.com/huggingface/transformers to /private/var/folders/kk/n4ff6h1n3t170b1m4zv09yf40000gn/T/pip-req-build-ih3h6ssg
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /private/var/folders/kk/n4ff6h1n3t170b1m4zv09yf40000gn/T/pip-req-build-ih3h6ssg
#   Resolved https://github.com/huggingface/transformers to commit 18ee1fe76295239335bf1528c744fe1cfba21cc8
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /Users/kevin/miniconda3/lib/python3.11/site-packages (from transformers==4.34.0.dev0) (3.12.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from transformers==4.34.0.dev0) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from transformers==4.34.0.dev0) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from transformers==4.34.0.dev0) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from transformers==4.34.0.dev0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from transformers==4.34.0.dev0) (2023.8.8)
# Requirement already satisfied: requests in /Users/kevin/miniconda3/lib/python3.11/site-packages (from transformers==4.34.0.dev0) (2.29.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from transformers==4.34.0.dev0) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from transformers==4.34.0.dev0) (0.3.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from transformers==4.34.0.dev0) (4.65.0)
# Requirement already satisfied: fsspec in /Users/kevin/miniconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers==4.34.0.dev0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers==4.34.0.dev0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from requests->transformers==4.34.0.dev0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from requests->transformers==4.34.0.dev0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from requests->transformers==4.34.0.dev0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from requests->transformers==4.34.0.dev0) (2023.7.22)
# Requirement already satisfied: librosa in /Users/kevin/miniconda3/lib/python3.11/site-packages (0.10.1)
# Requirement already satisfied: audioread>=2.1.9 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from librosa) (3.0.0)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from librosa) (1.24.4)
# Requirement already satisfied: scipy>=1.2.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from librosa) (1.11.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from librosa) (1.3.0)
# Requirement already satisfied: joblib>=0.14 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from librosa) (1.3.2)
# Requirement already satisfied: decorator>=4.3.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from librosa) (0.57.1)
# Requirement already satisfied: soundfile>=0.12.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from librosa) (1.7.0)
# Requirement already satisfied: soxr>=0.3.2 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from librosa) (0.3.6)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from librosa) (4.7.1)
# Requirement already satisfied: lazy-loader>=0.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from librosa) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from librosa) (1.0.5)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from numba>=0.51.0->librosa) (0.40.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from pooch>=1.0->librosa) (3.10.0)
# Requirement already satisfied: packaging>=20.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from pooch>=1.0->librosa) (23.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from pooch>=1.0->librosa) (2.29.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from scikit-learn>=0.20.0->librosa) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in /Users/kevin/miniconda3/lib/python3.11/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2023.7.22)
# Collecting evaluate==0.4.0
#   Using cached evaluate-0.4.0-py3-none-any.whl (81 kB)
# Requirement already satisfied: datasets>=2.0.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from evaluate==0.4.0) (2.14.5)
# Requirement already satisfied: numpy>=1.17 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from evaluate==0.4.0) (1.24.4)
# Requirement already satisfied: dill in /Users/kevin/miniconda3/lib/python3.11/site-packages (from evaluate==0.4.0) (0.3.7)
# Requirement already satisfied: pandas in /Users/kevin/miniconda3/lib/python3.11/site-packages (from evaluate==0.4.0) (2.1.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from evaluate==0.4.0) (2.29.0)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from evaluate==0.4.0) (4.65.0)
# Requirement already satisfied: xxhash in /Users/kevin/miniconda3/lib/python3.11/site-packages (from evaluate==0.4.0) (3.3.0)
# Requirement already satisfied: multiprocess in /Users/kevin/miniconda3/lib/python3.11/site-packages (from evaluate==0.4.0) (0.70.15)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from evaluate==0.4.0) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from evaluate==0.4.0) (0.16.4)
# Requirement already satisfied: packaging in /Users/kevin/miniconda3/lib/python3.11/site-packages (from evaluate==0.4.0) (23.0)
# Collecting responses<0.19 (from evaluate==0.4.0)
#   Using cached responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyarrow>=8.0.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from datasets>=2.0.0->evaluate==0.4.0) (13.0.0)
# Requirement already satisfied: aiohttp in /Users/kevin/miniconda3/lib/python3.11/site-packages (from datasets>=2.0.0->evaluate==0.4.0) (3.8.5)
# Requirement already satisfied: pyyaml>=5.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from datasets>=2.0.0->evaluate==0.4.0) (6.0.1)
# Requirement already satisfied: filelock in /Users/kevin/miniconda3/lib/python3.11/site-packages (from huggingface-hub>=0.7.0->evaluate==0.4.0) (3.12.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from huggingface-hub>=0.7.0->evaluate==0.4.0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from requests>=2.19.0->evaluate==0.4.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from requests>=2.19.0->evaluate==0.4.0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from requests>=2.19.0->evaluate==0.4.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from requests>=2.19.0->evaluate==0.4.0) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from pandas->evaluate==0.4.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from pandas->evaluate==0.4.0) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from pandas->evaluate==0.4.0) (2023.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.0) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.0) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.0) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.0) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.0) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.0) (1.3.1)
# Requirement already satisfied: six>=1.5 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->evaluate==0.4.0) (1.16.0)
# Installing collected packages: responses, evaluate
# Successfully installed evaluate-0.4.0 responses-0.18.0
# Requirement already satisfied: jiwer in /Users/kevin/miniconda3/lib/python3.11/site-packages (3.0.2)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from jiwer) (8.1.6)
# Requirement already satisfied: rapidfuzz==2.13.7 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from jiwer) (2.13.7)
# Requirement already satisfied: gradio in /Users/kevin/miniconda3/lib/python3.11/site-packages (3.43.2)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from gradio) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from gradio) (5.1.1)
# Requirement already satisfied: fastapi in /Users/kevin/miniconda3/lib/python3.11/site-packages (from gradio) (0.103.1)
# Requirement already satisfied: ffmpy in /Users/kevin/miniconda3/lib/python3.11/site-packages (from gradio) (0.3.1)
# Requirement already satisfied: gradio-client==0.5.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from gradio) (0.5.0)
# Requirement already satisfied: httpx in /Users/kevin/miniconda3/lib/python3.11/site-packages (from gradio) (0.24.1)
# Requirement already satisfied: huggingface-hub>=0.14.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from gradio) (0.16.4)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from gradio) (6.0.1)
# Requirement already satisfied: jinja2<4.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from gradio) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from gradio) (3.7.2)
# Requirement already satisfied: numpy~=1.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from gradio) (1.24.4)
# Requirement already satisfied: orjson~=3.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from gradio) (3.9.6)
# Requirement already satisfied: packaging in /Users/kevin/miniconda3/lib/python3.11/site-packages (from gradio) (23.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from gradio) (2.1.0)
# Requirement already satisfied: pillow<11.0,>=8.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from gradio) (10.0.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from gradio) (2.3.0)
# Requirement already satisfied: pydub in /Users/kevin/miniconda3/lib/python3.11/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart in /Users/kevin/miniconda3/lib/python3.11/site-packages (from gradio) (0.0.6)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from gradio) (6.0.1)
# Requirement already satisfied: requests~=2.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from gradio) (2.29.0)
# Requirement already satisfied: semantic-version~=2.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: typing-extensions~=4.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from gradio) (4.7.1)
# Requirement already satisfied: uvicorn>=0.14.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from gradio) (0.23.2)
# Requirement already satisfied: websockets<12.0,>=10.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from gradio) (11.0.3)
# Requirement already satisfied: fsspec in /Users/kevin/miniconda3/lib/python3.11/site-packages (from gradio-client==0.5.0->gradio) (2023.6.0)
# Requirement already satisfied: jsonschema>=3.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from altair<6.0,>=4.2.0->gradio) (4.19.0)
# Requirement already satisfied: toolz in /Users/kevin/miniconda3/lib/python3.11/site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: filelock in /Users/kevin/miniconda3/lib/python3.11/site-packages (from huggingface-hub>=0.14.0->gradio) (3.12.3)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from huggingface-hub>=0.14.0->gradio) (4.65.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from matplotlib~=3.0->gradio) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from matplotlib~=3.0->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from matplotlib~=3.0->gradio) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from matplotlib~=3.0->gradio) (1.4.5)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from matplotlib~=3.0->gradio) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from pandas<3.0,>=1.0->gradio) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4->gradio) (0.5.0)
# Requirement already satisfied: pydantic-core==2.6.3 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4->gradio) (2.6.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from requests~=2.0->gradio) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from requests~=2.0->gradio) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from requests~=2.0->gradio) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from requests~=2.0->gradio) (2023.7.22)
# Requirement already satisfied: click>=7.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from uvicorn>=0.14.0->gradio) (8.1.6)
# Requirement already satisfied: h11>=0.8 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from uvicorn>=0.14.0->gradio) (0.14.0)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from fastapi->gradio) (3.7.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from fastapi->gradio) (0.27.0)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from httpx->gradio) (0.17.3)
# Requirement already satisfied: sniffio in /Users/kevin/miniconda3/lib/python3.11/site-packages (from httpx->gradio) (1.3.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.10.2)
# Requirement already satisfied: six>=1.5 in /Users/kevin/miniconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)

# %% [markdown]
# We strongly advise you to upload model checkpoints directly the [Hugging Face Hub](https://huggingface.co/)
# whilst training. The Hub provides:
# - Integrated version control: you can be sure that no model checkpoint is lost during training.
# - Tensorboard logs: track important metrics over the course of training.
# - Model cards: document what a model does and its intended use cases.
# - Community: an easy way to share and collaborate with the community!
#
# Linking the notebook to the Hub is straightforward - it simply requires entering your
# Hub authentication token when prompted. Find your Hub authentication token [here](https://huggingface.co/settings/tokens):

# %%
from huggingface_hub import login

# TODO: replace with your own token
login(token="hf_XXX")
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /Users/kevin/.cache/huggingface/token
# Login successful

# %% [markdown]
# ## Load Dataset

# %% [markdown]
# Using 🤗 Datasets, downloading and preparing data is extremely simple.
# We can download and prepare the Common Voice splits in just one line of code.
#
# First, ensure you have accepted the terms of use on the Hugging Face Hub: [mozilla-foundation/common_voice_11_0](https://huggingface.co/datasets/mozilla-foundation/common_voice_11_0). Once you have accepted the terms, you will have full access to the dataset and be able to download the data locally.
#
# Since Hindi is very low-resource, we'll combine the `train` and `validation`
# splits to give approximately 8 hours of training data. We'll use the 4 hours
# of `test` data as our held-out test set:

# %%
from datasets import load_dataset
common_voice = load_dataset("audiofolder", data_dir="yue")
# Out:
# Resolving data files:   0%|          | 0/73020 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/2561 [00:00<?, ?it/s]
# Downloading data files:   0%|          | 0/73020 [00:00<?, ?it/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data files:   0%|          | 0/2561 [00:00<?, ?it/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %% [markdown]
# Most ASR datasets only provide input audio samples (`audio`) and the
# corresponding transcribed text (`sentence`). Common Voice contains additional
# metadata information, such as `accent` and `locale`, which we can disregard for ASR.
# Keeping the notebook as general as possible, we only consider the input audio and
# transcribed text for fine-tuning, discarding the additional metadata information:

# %%
print(common_voice)
print(common_voice["train"][0])
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['audio', 'transcription'],
#         num_rows: 73019
#     })
#     validation: Dataset({
#         features: ['audio', 'transcription'],
#         num_rows: 0
#     })
#     test: Dataset({
#         features: ['audio', 'transcription'],
#         num_rows: 2560
#     })
# })
# {'audio': {'path': '/Users/kevin/Dev/personal/wav2jyutping/yue/data/train/common_voice_yue_31172849.mp3', 'array': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#        1.19394615e-04, 9.48327288e-05, 1.03248676e-04]), 'sampling_rate': 32000}, 'transcription': 'ngo dou hou hou kei dim gaai nei m zung ji ngo'}

# %% [markdown]
# ## Prepare Feature Extractor, Tokenizer and Data

# %% [markdown]
# The ASR pipeline can be de-composed into three stages:
# 1) A feature extractor which pre-processes the raw audio-inputs
# 2) The model which performs the sequence-to-sequence mapping
# 3) A tokenizer which post-processes the model outputs to text format
#
# In 🤗 Transformers, the Whisper model has an associated feature extractor and tokenizer,
# called [WhisperFeatureExtractor](https://huggingface.co/docs/transformers/main/model_doc/whisper#transformers.WhisperFeatureExtractor)
# and [WhisperTokenizer](https://huggingface.co/docs/transformers/main/model_doc/whisper#transformers.WhisperTokenizer)
# respectively.
#
# We'll go through details for setting-up the feature extractor and tokenizer one-by-one!

# %% [markdown]
# ### Load WhisperFeatureExtractor

# %% [markdown]
# The Whisper feature extractor performs two operations:
# 1. Pads / truncates the audio inputs to 30s: any audio inputs shorter than 30s are padded to 30s with silence (zeros), and those longer that 30s are truncated to 30s
# 2. Converts the audio inputs to _log-Mel spectrogram_ input features, a visual representation of the audio and the form of the input expected by the Whisper model

# %% [markdown]
# <figure>
# <img src="https://raw.githubusercontent.com/sanchit-gandhi/notebooks/main/spectrogram.jpg" alt="Trulli" style="width:100%">
# <figcaption align = "center"><b>Figure 2:</b> Conversion of sampled audio array to log-Mel spectrogram.
# Left: sampled 1-dimensional audio signal. Right: corresponding log-Mel spectrogram. Figure source:
# <a href="https://ai.googleblog.com/2019/04/specaugment-new-data-augmentation.html">Google SpecAugment Blog</a>.
# </figcaption>

# %% [markdown]
# We'll load the feature extractor from the pre-trained checkpoint with the default values:

# %%
from transformers import WhisperFeatureExtractor

feature_extractor = WhisperFeatureExtractor.from_pretrained("openai/whisper-small")

# %% [markdown]
# ### Load WhisperTokenizer

# %% [markdown]
# The Whisper model outputs a sequence of _token ids_. The tokenizer maps each of these token ids to their corresponding text string. For Hindi, we can load the pre-trained tokenizer and use it for fine-tuning without any further modifications. We simply have to
# specify the target language and the task. These arguments inform the
# tokenizer to prefix the language and task tokens to the start of encoded
# label sequences:

# %%
from transformers import WhisperTokenizer

# Use english because jyutping shares the same alphabet
tokenizer = WhisperTokenizer.from_pretrained("openai/whisper-small", language="english", task="transcribe")

# %% [markdown]
# ### Combine To Create A WhisperProcessor

# %% [markdown]
# To simplify using the feature extractor and tokenizer, we can _wrap_
# both into a single `WhisperProcessor` class. This processor object
# inherits from the `WhisperFeatureExtractor` and `WhisperProcessor`,
# and can be used on the audio inputs and model predictions as required.
# In doing so, we only need to keep track of two objects during training:
# the `processor` and the `model`:

# %%
from transformers import WhisperProcessor

# Use english because jyutping shares the same alphabet
processor = WhisperProcessor.from_pretrained("openai/whisper-small", language="english", task="transcribe")

# %% [markdown]
# ### Prepare Data

# %% [markdown]
# Let's print the first example of the Common Voice dataset to see
# what form the data is in:

# %%
print(common_voice["train"][0])
# Out:
# {'audio': {'path': '/Users/kevin/Dev/personal/wav2jyutping/yue/data/train/common_voice_yue_31172849.mp3', 'array': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#        1.19394615e-04, 9.48327288e-05, 1.03248676e-04]), 'sampling_rate': 32000}, 'transcription': 'ngo dou hou hou kei dim gaai nei m zung ji ngo'}

# %% [markdown]
# Since
# our input audio is sampled at 48kHz, we need to _downsample_ it to
# 16kHz prior to passing it to the Whisper feature extractor, 16kHz being the sampling rate expected by the Whisper model.
#
# We'll set the audio inputs to the correct sampling rate using dataset's
# [`cast_column`](https://huggingface.co/docs/datasets/package_reference/main_classes.html?highlight=cast_column#datasets.DatasetDict.cast_column)
# method. This operation does not change the audio in-place,
# but rather signals to `datasets` to resample audio samples _on the fly_ the
# first time that they are loaded:

# %%
from datasets import Audio

common_voice = common_voice.cast_column("audio", Audio(sampling_rate=16000))

# %% [markdown]
# Re-loading the first audio sample in the Common Voice dataset will resample
# it to the desired sampling rate:

# %%
print(common_voice["train"][0])
# Out:
# {'audio': {'path': '/Users/kevin/Dev/personal/wav2jyutping/yue/data/train/common_voice_yue_31172849.mp3', 'array': array([ 6.93889390e-18, -6.93889390e-18,  8.67361738e-18, ...,
#         5.13813866e-05,  1.36585470e-04,  1.06401014e-04]), 'sampling_rate': 16000}, 'transcription': 'ngo dou hou hou kei dim gaai nei m zung ji ngo'}

# %% [markdown]
# Now we can write a function to prepare our data ready for the model:
# 1. We load and resample the audio data by calling `batch["audio"]`. As explained above, 🤗 Datasets performs any necessary resampling operations on the fly.
# 2. We use the feature extractor to compute the log-Mel spectrogram input features from our 1-dimensional audio array.
# 3. We encode the transcriptions to label ids through the use of the tokenizer.

# %%
def prepare_dataset(batch):
    # load and resample audio data from 48 to 16kHz
    audio = batch["audio"]

    # compute log-Mel input features from input audio array
    batch["input_features"] = processor.feature_extractor(audio["array"], sampling_rate=audio["sampling_rate"]).input_features[0]

    # encode target text to label ids
    batch["labels"] = processor.tokenizer(batch["transcription"]).input_ids
    return batch

# %% [markdown]
# We can apply the data preparation function to all of our training examples using dataset's `.map` method. The argument `num_proc` specifies how many CPU cores to use. Setting `num_proc` > 1 will enable multiprocessing. If the `.map` method hangs with multiprocessing, set `num_proc=1` and process the dataset sequentially.

# %%
common_voice = common_voice.map(prepare_dataset, remove_columns=common_voice.column_names["train"], num_proc=10)
# Out:
# Map (num_proc=10):   0%|          | 0/73019 [00:00<?, ? examples/s]
# Map (num_proc=10):   0%|          | 0/2560 [00:00<?, ? examples/s]

# %% [markdown]
# ## Training and Evaluation

# %% [markdown]
# Now that we've prepared our data, we're ready to dive into the training pipeline.
# The [🤗 Trainer](https://huggingface.co/transformers/master/main_classes/trainer.html?highlight=trainer)
# will do much of the heavy lifting for us. All we have to do is:
#
# - Define a data collator: the data collator takes our pre-processed data and prepares PyTorch tensors ready for the model.
#
# - Evaluation metrics: during evaluation, we want to evaluate the model using the [word error rate (WER)](https://huggingface.co/metrics/wer) metric. We need to define a `compute_metrics` function that handles this computation.
#
# - Load a pre-trained checkpoint: we need to load a pre-trained checkpoint and configure it correctly for training.
#
# - Define the training configuration: this will be used by the 🤗 Trainer to define the training schedule.
#
# Once we've fine-tuned the model, we will evaluate it on the test data to verify that we have correctly trained it
# to transcribe speech in Hindi.

# %% [markdown]
# ### Define a Data Collator

# %% [markdown]
# The data collator for a sequence-to-sequence speech model is unique in the sense that it
# treats the `input_features` and `labels` independently: the  `input_features` must be
# handled by the feature extractor and the `labels` by the tokenizer.
#
# The `input_features` are already padded to 30s and converted to a log-Mel spectrogram
# of fixed dimension by action of the feature extractor, so all we have to do is convert the `input_features`
# to batched PyTorch tensors. We do this using the feature extractor's `.pad` method with `return_tensors=pt`.
#
# The `labels` on the other hand are un-padded. We first pad the sequences
# to the maximum length in the batch using the tokenizer's `.pad` method. The padding tokens
# are then replaced by `-100` so that these tokens are **not** taken into account when
# computing the loss. We then cut the BOS token from the start of the label sequence as we
# append it later during training.
#
# We can leverage the `WhisperProcessor` we defined earlier to perform both the
# feature extractor and the tokenizer operations:

# %%
import torch

from dataclasses import dataclass
from typing import Any, Dict, List, Union

@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:
    processor: Any

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lengths and need different padding methods
        # first treat the audio inputs by simply returning torch tensors
        input_features = [{"input_features": feature["input_features"]} for feature in features]
        batch = self.processor.feature_extractor.pad(input_features, return_tensors="pt")

        # get the tokenized label sequences
        label_features = [{"input_ids": feature["labels"]} for feature in features]
        # pad the labels to max length
        labels_batch = self.processor.tokenizer.pad(label_features, return_tensors="pt")

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        # if bos token is appended in previous tokenization step,
        # cut bos token here as it's append later anyways
        if (labels[:, 0] == self.processor.tokenizer.bos_token_id).all().cpu().item():
            labels = labels[:, 1:]

        batch["labels"] = labels

        return batch

# %% [markdown]
# Let's initialise the data collator we've just defined:

# %%
data_collator = DataCollatorSpeechSeq2SeqWithPadding(processor=processor)

# %% [markdown]
# ### Evaluation Metrics

# %% [markdown]
# We'll use the word error rate (WER) metric, the 'de-facto' metric for assessing
# ASR systems. For more information, refer to the WER [docs](https://huggingface.co/metrics/wer). We'll load the WER metric from 🤗 Evaluate:

# %%
import evaluate

metric = evaluate.load("wer")

# %% [markdown]
# We then simply have to define a function that takes our model
# predictions and returns the WER metric. This function, called
# `compute_metrics`, first replaces `-100` with the `pad_token_id`
# in the `label_ids` (undoing the step we applied in the
# data collator to ignore padded tokens correctly in the loss).
# It then decodes the predicted and label ids to strings. Finally,
# it computes the WER between the predictions and reference labels:

# %%
def compute_metrics(pred):
    pred_ids = pred.predictions
    label_ids = pred.label_ids

    # replace -100 with the pad_token_id
    label_ids[label_ids == -100] = tokenizer.pad_token_id

    # we do not want to group tokens when computing the metrics
    pred_str = tokenizer.batch_decode(pred_ids, skip_special_tokens=True)
    label_str = tokenizer.batch_decode(label_ids, skip_special_tokens=True)

    wer = 100 * metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %% [markdown]
# ### Load a Pre-Trained Checkpoint

# %% [markdown]
# Now let's load the pre-trained Whisper `tiny` checkpoint. Again, this
# is trivial through use of 🤗 Transformers!

# %%
from transformers import WhisperForConditionalGeneration

model = WhisperForConditionalGeneration.from_pretrained("openai/whisper-small")

# %% [markdown]
# Override generation arguments - no tokens are forced as decoder outputs (see [`forced_decoder_ids`](https://huggingface.co/docs/transformers/main_classes/text_generation#transformers.generation_utils.GenerationMixin.generate.forced_decoder_ids)), no tokens are suppressed during generation (see [`suppress_tokens`](https://huggingface.co/docs/transformers/main_classes/text_generation#transformers.generation_utils.GenerationMixin.generate.suppress_tokens)):

# %%
model.config.forced_decoder_ids = None
model.config.suppress_tokens = []

# %% [markdown]
# ### Define the Training Configuration

# %% [markdown]
# In the final step, we define all the parameters related to training. For more detail on the training arguments, refer to the Seq2SeqTrainingArguments [docs](https://huggingface.co/docs/transformers/main_classes/trainer#transformers.Seq2SeqTrainingArguments).

# %%
from transformers import Seq2SeqTrainingArguments

training_args = Seq2SeqTrainingArguments(
    output_dir="./whisper-small-jyutping-without-tones-full",  # change to a repo name of your choice
    per_device_train_batch_size=16,
    gradient_accumulation_steps=1,  # increase by 2x for every 2x decrease in batch size
    learning_rate=1e-5,
    warmup_steps=400,
    max_steps=2400,
    gradient_checkpointing=True,
    fp16=False,
    use_mps_device=True,
    evaluation_strategy="steps",
    per_device_eval_batch_size=16,
    predict_with_generate=True,
    generation_max_length=225,
    save_steps=800,
    eval_steps=800,
    logging_steps=25,
    report_to=["tensorboard"],
    load_best_model_at_end=True,
    metric_for_best_model="wer",
    greater_is_better=False,
    push_to_hub=False,
)
# Out:
# /Users/kevin/miniconda3/lib/python3.11/site-packages/transformers/training_args.py:1844: UserWarning: `use_mps_device` is deprecated and will be removed in version 5.0 of 🤗 Transformers.`mps` device will be used by default if available similar to the way `cuda` device is used.Therefore, no action from user is required.
#   warnings.warn(

# %% [markdown]
# **Note**: if one does not want to upload the model checkpoints to the Hub,
# set `push_to_hub=False`.

# %% [markdown]
# We can forward the training arguments to the 🤗 Trainer along with our model,
# dataset, data collator and `compute_metrics` function:

# %%
from transformers import Seq2SeqTrainer

trainer = Seq2SeqTrainer(
    args=training_args,
    model=model,
    train_dataset=common_voice["train"],
    eval_dataset=common_voice["test"],
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    tokenizer=processor.feature_extractor,
)

# %% [markdown]
# We'll save the processor object once before starting training. Since the processor is not trainable, it won't change over the course of training:

# %%
processor.save_pretrained(training_args.output_dir)

# %% [markdown]
# ### Training

# %% [markdown]
# Training will take approximately 5-10 hours depending on your GPU or the one
# allocated to this Google Colab. If using this Google Colab directly to
# fine-tune a Whisper model, you should make sure that training isn't
# interrupted due to inactivity. A simple workaround to prevent this is
# to paste the following code into the console of this tab (_right mouse click_
# -> _inspect_ -> _Console tab_ -> _insert code_).

# %% [markdown]
# ```javascript
# function ConnectButton(){
#     console.log("Connect pushed");
#     document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click()
# }
# setInterval(ConnectButton, 60000);
# ```

# %% [markdown]
# The peak GPU memory for the given training configuration is approximately 15.8GB.
# Depending on the GPU allocated to the Google Colab, it is possible that you will encounter a CUDA `"out-of-memory"` error when you launch training.
# In this case, you can reduce the `per_device_train_batch_size` incrementally by factors of 2
# and employ [`gradient_accumulation_steps`](https://huggingface.co/docs/transformers/main_classes/trainer#transformers.Seq2SeqTrainingArguments.gradient_accumulation_steps)
# to compensate.
#
# To launch training, simply execute:

# %%
trainer.train()
# Out:
#   0%|          | 0/2400 [00:00<?, ?it/s]
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# {'loss': 3.4111, 'learning_rate': 6.25e-07, 'epoch': 0.01}
# {'loss': 2.7127, 'learning_rate': 1.25e-06, 'epoch': 0.01}
# {'loss': 1.6909, 'learning_rate': 1.8750000000000003e-06, 'epoch': 0.02}
# {'loss': 1.0658, 'learning_rate': 2.5e-06, 'epoch': 0.02}
# {'loss': 0.727, 'learning_rate': 3.125e-06, 'epoch': 0.03}
# {'loss': 0.577, 'learning_rate': 3.7500000000000005e-06, 'epoch': 0.03}
# {'loss': 0.4648, 'learning_rate': 4.3750000000000005e-06, 'epoch': 0.04}
# {'loss': 0.414, 'learning_rate': 5e-06, 'epoch': 0.04}
# {'loss': 0.3333, 'learning_rate': 5.625e-06, 'epoch': 0.05}
# {'loss': 0.2772, 'learning_rate': 6.25e-06, 'epoch': 0.05}
# {'loss': 0.1898, 'learning_rate': 6.875e-06, 'epoch': 0.06}
# {'loss': 0.1644, 'learning_rate': 7.500000000000001e-06, 'epoch': 0.07}
# {'loss': 0.1399, 'learning_rate': 8.125000000000001e-06, 'epoch': 0.07}
# {'loss': 0.142, 'learning_rate': 8.750000000000001e-06, 'epoch': 0.08}
# {'loss': 0.1269, 'learning_rate': 9.375000000000001e-06, 'epoch': 0.08}
# {'loss': 0.1451, 'learning_rate': 1e-05, 'epoch': 0.09}
# {'loss': 0.1317, 'learning_rate': 9.875000000000001e-06, 'epoch': 0.09}
# {'loss': 0.1393, 'learning_rate': 9.75e-06, 'epoch': 0.1}
 'learning_rate': 1.0000000000000002e-06, 'epoch': 0.48}
# {'loss': 0.0617, 'learning_rate': 8.75e-07, 'epoch': 0.49}
# {'loss': 0.065, 'learning_rate': 7.5e-07, 'epoch': 0.49}
# {'loss': 0.0547, 'learning_rate': 6.25e-07, 'epoch': 0.5}
# {'loss': 0.0696, 'learning_rate': 5.000000000000001e-07, 'epoch': 0.5}
# {'loss': 0.0511, 'learning_rate': 3.75e-07, 'epoch': 0.51}
# {'loss': 0.0568, 'learning_rate': 2.5000000000000004e-07, 'epoch': 0.51}
# {'loss': 0.0619, 'learning_rate': 1.2500000000000002e-07, 'epoch': 0.52}
# {'loss': 0.0555, 'learning_rate': 0.0, 'epoch': 0.53}
#   0%|          | 0/160 [00:00<?, ?it/s]
# {'eval_loss': 0.04725406691431999, 'eval_wer': 4.508933924931046, 'eval_runtime': 819.2354, 'eval_samples_per_second': 3.125, 'eval_steps_per_second': 0.195, 'epoch': 0.53}
# {'train_runtime': 19270.9466, 'train_samples_per_second': 1.993, 'train_steps_per_second': 0.125, 'train_loss': 0.19492529436945916, 'epoch': 0.53}
# TrainOutput(global_step=2400, training_loss=0.19492529436945916, metrics={'train_runtime': 19270.9466, 'train_samples_per_second': 1.993, 'train_steps_per_second': 0.125, 'train_loss': 0.19492529436945916, 'epoch': 0.53})

# %% [markdown]
# Our best WER is 32.0% - not bad for 8h of training data! We can submit our checkpoint to the [`hf-speech-bench`](https://huggingface.co/spaces/huggingface/hf-speech-bench) on push by setting the appropriate key-word arguments (kwargs):

# %%
kwargs = {
    "dataset": "Common Voice 14.0",  # a 'pretty' name for the training dataset
    "language": "yue",
    "model_name": "Whisper Small Jyutping without Tones Full Version",  # a 'pretty' name for our model
    "finetuned_from": "openai/whisper-small",
    "tasks": "automatic-speech-recognition",
}

# %% [markdown]
# The training results can now be uploaded to the Hub. To do so, execute the `push_to_hub` command and save the preprocessor object we created:

# %%
trainer.push_to_hub(**kwargs)
# Out:
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# training_args.bin:   0%|          | 0.00/4.28k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# 'https://huggingface.co/AlienKevin/whisper-small-jyutping-without-tones-full/tree/main/'

# %% [markdown]
# # Tests

# %%
from transformers import WhisperProcessor, WhisperForConditionalGeneration
from datasets import load_dataset

# load model and processor
processor = WhisperProcessor.from_pretrained("AlienKevin/whisper-small-jyutping-without-tones-full")
model = WhisperForConditionalGeneration.from_pretrained("AlienKevin/whisper-small-jyutping-without-tones-full")
model.config.forced_decoder_ids = None

# load dummy dataset and read audio files
from datasets import load_dataset
from datasets import Audio
test_data = load_dataset("audiofolder", data_dir="yue", split="test")
test_data = test_data.cast_column("audio", Audio(sampling_rate=16000))

import torch

def map_to_pred(batch):
    audio = batch["audio"]
    input_features = processor(audio["array"], sampling_rate=audio["sampling_rate"], return_tensors="pt").input_features
    batch["reference"] = processor.tokenizer._normalize(batch["transcription"])

    with torch.no_grad():
        predicted_ids = model.generate(input_features)[0]
    transcription = processor.decode(predicted_ids)
    batch["prediction"] = processor.tokenizer._normalize(transcription)

    return batch

result = test_data.map(map_to_pred)

import evaluate
metric = evaluate.load("wer")
print("WER:")
print(100 * metric.compute(references=result["reference"], predictions=result["prediction"]))

with open("whisper-small-jyutping-without-tones-full-test-output.txt", "w+") as f:
    for r, p in zip(result["reference"], result["prediction"]):
        f.write(r + "\n" + p + "\n\n")
# Out:
# Downloading (…)rocessor_config.json:   0%|          | 0.00/339 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/805 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# Downloading (…)main/normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# Downloading (…)in/added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/2.08k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.32k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/3.84k [00:00<?, ?B/s]
# Resolving data files:   0%|          | 0/73020 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/2561 [00:00<?, ?it/s]
# Map:   0%|          | 0/2560 [00:00<?, ? examples/s]
# WER:
# 4.508933924931046

# %% [markdown]
# ## Building a Demo

# %% [markdown]
# Now that we've fine-tuned our model we can build a demo to show
# off its ASR capabilities! We'll make use of 🤗 Transformers
# `pipeline`, which will take care of the entire ASR pipeline,
# right from pre-processing the audio inputs to decoding the
# model predictions.
#
# Running the example below will generate a Gradio demo where we
# can record speech through the microphone of our computer and input it to
# our fine-tuned Whisper model to transcribe the corresponding text:

# %%
from transformers import pipeline
import gradio as gr

pipe = pipeline(model="AlienKevin/whisper-small-jyutping-without-tones-full", task="automatic-speech-recognition")  # change to "your-username/the-name-you-picked"

def transcribe(audio):
    text = pipe(audio)["text"]
    return text

iface = gr.Interface(
    fn=transcribe,
    inputs=gr.Audio(source="microphone", type="filepath"),
    outputs="text",
    title="Whisper Small Jyutping without Tones",
    description="Realtime demo for Jyutping transcription using a fine-tuned Whisper small model.",
)

iface.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7862
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# /Users/kevin/miniconda3/lib/python3.11/site-packages/gradio/processing_utils.py:188: UserWarning: Trying to convert audio automatically from int32 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
# /Users/kevin/miniconda3/lib/python3.11/site-packages/gradio/processing_utils.py:188: UserWarning: Trying to convert audio automatically from int32 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
# /Users/kevin/miniconda3/lib/python3.11/site-packages/gradio/processing_utils.py:188: UserWarning: Trying to convert audio automatically from int32 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
# /Users/kevin/miniconda3/lib/python3.11/site-packages/gradio/processing_utils.py:188: UserWarning: Trying to convert audio automatically from int32 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))
# /Users/kevin/miniconda3/lib/python3.11/site-packages/gradio/processing_utils.py:188: UserWarning: Trying to convert audio automatically from int32 to 16-bit int format.
#   warnings.warn(warning.format(data.dtype))

# %% [markdown]
# # Convert to PyTorch model

# %%
# !pip install git+https://github.com/bayartsogt-ya/whisper-multiple-hf-datasets

from multiple_datasets.hub_default_utils import convert_hf_whisper

convert_hf_whisper("AlienKevin/whisper-small-jyutping-without-tones-full", "small.pt")
# Out:
# Collecting git+https://github.com/bayartsogt-ya/whisper-multiple-hf-datasets
#   Cloning https://github.com/bayartsogt-ya/whisper-multiple-hf-datasets to /private/var/folders/kk/n4ff6h1n3t170b1m4zv09yf40000gn/T/pip-req-build-f252yxm_
#   Running command git clone --filter=blob:none --quiet https://github.com/bayartsogt-ya/whisper-multiple-hf-datasets /private/var/folders/kk/n4ff6h1n3t170b1m4zv09yf40000gn/T/pip-req-build-f252yxm_
#   Resolved https://github.com/bayartsogt-ya/whisper-multiple-hf-datasets to commit 73d9f012cb19f4e0cfe43820b12b6a9da8eb8ea1
#   Preparing metadata (setup.py) ... done
# encoder.conv1.weight -> encoder.conv1.weight
# encoder.conv1.bias -> encoder.conv1.bias
# encoder.conv2.weight -> encoder.conv2.weight
# encoder.conv2.bias -> encoder.conv2.bias
# encoder.embed_positions.weight -> encoder.positional_embedding
# encoder.layers.0.self_attn.k_proj.weight -> encoder.blocks.0.attn.key.weight
# encoder.layers.0.self_attn.v_proj.weight -> encoder.blocks.0.attn.value.weight
# encoder.layers.0.self_attn.v_proj.bias -> encoder.blocks.0.attn.value.bias
# encoder.layers.0.self_attn.q_proj.weight -> encoder.blocks.0.attn.query.weight
# encoder.layers.0.self_attn.q_proj.bias -> encoder.blocks.0.attn.query.bias
# encoder.layers.0.self_attn.out_proj.weight -> encoder.blocks.0.attn.out.weight
# encoder.layers.10.self_attn.out_proj.bias -> encoder.blocks.10.attn.out.bias
# encoder.layers.10.self_attn_layer_norm.weight -> encoder.blocks.10.attn_ln.weight
# encoder.layers.10.self_attn_layer_norm.bias -> encoder.blocks.10.attn_ln.bias
# encoder.layers.10.fc1.weight -> encoder.blocks.10.mlp.0.weight
# encoder.layers.10.fc1.bias -> encoder.blocks.10.mlp.0.bias
# encoder.layers.10.fc2.weight -> encoder.blocks.10.mlp.2.weight
# encoder.layers.10.fc2.bias -> encoder.blocks.10.mlp.2.bias
# encoder.layers.10.final_layer_norm.weight -> encoder.blocks.10.mlp_ln.weight
# encoder.layers.10.final_layer_norm.bias -> encoder.blocks.10.mlp_ln.bias
# encoder.layers.11.self_attn.k_proj.weight -> encoder.blocks.11.attn.key.weight
# encoder.layers.11.self_attn.v_proj.weight -> encoder.blocks.11.attn.value.weight
# encoder.layers.11.self_attn.v_proj.bias -> encoder.blocks.11.attn.value.bias
# encoder.layers.11.self_attn.q_proj.weight -> encoder.blocks.11.attn.query.weight
# encoder.layers.11.self_attn.q_proj.bias -> encoder.blocks.11.attn.query.bias
# encoder.layers.11.self_attn.out_proj.weight -> encoder.blocks.11.attn.out.weight
# encoder.layers.11.self_attn.out_proj.bias -> encoder.blocks.11.attn.out.bias
# encoder.layers.11.self_attn_layer_norm.weight -> encoder.blocks.11.attn_ln.weight
# encoder.layers.11.self_attn_layer_norm.bias -> encoder.blocks.11.attn_ln.bias
# encoder.layers.11.fc1.weight -> encoder.blocks.11.mlp.0.weight
# encoder.layers.11.fc1.bias -> encoder.blocks.11.mlp.0.bias
# encoder.layers.11.fc2.weight -> encoder.blocks.11.mlp.2.weight
# encoder.layers.11.fc2.bias -> encoder.blocks.11.mlp.2.bias
# encoder.layers.11.final_layer_norm.weight -> encoder.blocks.11.mlp_ln.weight
# encoder.layers.11.final_layer_norm.bias -> encoder.blocks.11.mlp_ln.bias
# encoder.layer_norm.weight -> encoder.ln_post.weight
# encoder.layer_norm.bias -> encoder.ln_post.bias
# decoder.embed_tokens.weight -> decoder.token_embedding.weight
# decoder.embed_positions.weight -> decoder.positional_embedding
# decoder.layers.0.self_attn.k_proj.weight -> decoder.blocks.0.attn.key.weight
# decoder.layers.0.self_attn.v_proj.weight -> decoder.blocks.0.attn.value.weight
# decoder.layers.0.self_attn.v_proj.bias -> decoder.blocks.0.attn.value.bias
# decoder.layers.0.self_attn.q_proj.weight -> decoder.blocks.0.attn.query.weight
# decoder.layers.0.self_attn.q_proj.bias -> decoder.blocks.0.attn.query.bias
# decoder.layers.0.self_attn.out_proj.weight -> decoder.blocks.0.attn.out.weight
# decoder.layers.0.self_attn.out_proj.bias -> decoder.blocks.0.attn.out.bias
# decoder.layers.0.self_attn_layer_norm.weight -> decoder.blocks.0.attn_ln.weight
# decoder.layers.0.self_attn_layer_norm.bias -> decoder.blocks.0.attn_ln.bias
# decoder.layers.0.encoder_attn.k_proj.weight -> decoder.blocks.0.cross_attn.key.weight
# decoder.layers.0.encoder_attn.v_proj.weight -> decoder.blocks.0.cross_attn.value.weight
# decoder.layers.0.encoder_attn.v_proj.bias -> decoder.blocks.0.cross_attn.value.bias
# decoder.layers.0.encoder_attn.q_proj.weight -> decoder.blocks.0.cross_attn.query.weight
# decoder.layers.0.encoder_attn.q_proj.bias -> decoder.blocks.0.cross_attn.query.bias
# decoder.layers.0.encoder_attn.out_proj.weight -> decoder.blocks.0.cross_attn.out.weight
# decoder.layers.0.encoder_attn.out_proj.bias -> decoder.blocks.0.cross_attn.out.bias
# decoder.layers.0.encoder_attn_layer_norm.weight -> decoder.blocks.0.cross_attn_ln.weight
# decoder.layers.0.encoder_attn_layer_norm.bias -> decoder.blocks.0.cross_attn_ln.bias
# decoder.layers.0.fc1.weight -> decoder.blocks.0.mlp.0.weight
# decoder.layers.0.fc1.bias -> decoder.blocks.0.mlp.0.bias
# decoder.layers.0.fc2.weight -> decoder.blocks.0.mlp.2.weight
# decoder.layers.0.fc2.bias -> decoder.blocks.0.mlp.2.bias
# decoder.layers.0.final_layer_norm.weight -> decoder.blocks.0.mlp_ln.weight
# decoder.layers.0.final_layer_norm.bias -> decoder.blocks.0.mlp_ln.bias
# decoder.layers.1.self_attn.k_proj.weight -> decoder.blocks.1.attn.key.weight
# decoder.layers.1.self_attn.v_proj.weight -> decoder.blocks.1.attn.value.weight
# decoder.layers.1.self_attn.v_proj.bias -> decoder.blocks.1.attn.value.bias
# decoder.layers.1.self_attn.q_proj.weight -> decoder.blocks.1.attn.query.weight
# decoder.layers.1.self_attn.q_proj.bias -> decoder.blocks.1.attn.query.bias
# decoder.layers.1.self_attn.out_proj.weight -> decoder.blocks.1.attn.out.weight
# decoder.layers.1.self_attn.out_proj.bias -> decoder.blocks.1.attn.out.bias
# decoder.layers.1.self_attn_layer_norm.weight -> decoder.blocks.1.attn_ln.weight
# decoder.layers.1.self_attn_layer_norm.bias -> decoder.blocks.1.attn_ln.bias
# decoder.layers.1.encoder_attn.k_proj.weight -> decoder.blocks.1.cross_attn.key.weight
# decoder.layers.1.encoder_attn.v_proj.weight -> decoder.blocks.1.cross_attn.value.weight
# decoder.layers.1.encoder_attn.v_proj.bias -> decoder.blocks.1.cross_attn.value.bias
# decoder.layers.1.encoder_attn.q_proj.weight -> decoder.blocks.1.cross_attn.query.weight
# decoder.layers.1.encoder_attn.q_proj.bias -> decoder.blocks.1.cross_attn.query.bias
# decoder.layers.1.encoder_attn.out_proj.weight -> decoder.blocks.1.cross_attn.out.weight
# decoder.layers.1.encoder_attn.out_proj.bias -> decoder.blocks.1.cross_attn.out.bias
# decoder.layers.1.encoder_attn_layer_norm.weight -> decoder.blocks.1.cross_attn_ln.weight
# decoder.layers.1.encoder_attn_layer_norm.bias -> decoder.blocks.1.cross_attn_ln.bias
# decoder.layers.1.fc1.weight -> decoder.blocks.1.mlp.0.weight
# decoder.layers.1.fc1.bias -> decoder.blocks.1.mlp.0.bias
# decoder.layers.1.fc2.weight -> decoder.blocks.1.mlp.2.weight
# decoder.layers.1.fc2.bias -> decoder.blocks.1.mlp.2.bias
# decoder.layers.1.final_layer_norm.weight -> decoder.blocks.1.mlp_ln.weight
# decoder.layers.1.final_layer_norm.bias -> decoder.blocks.1.mlp_ln.bias
# decoder.layers.2.self_attn.k_proj.weight -> decoder.blocks.2.attn.key.weight
# decoder.layers.2.self_attn.v_proj.weight -> decoder.blocks.2.attn.value.weight
# decoder.layers.2.self_attn.v_proj.bias -> decoder.blocks.2.attn.value.bias
# decoder.layers.2.self_attn.q_proj.weight -> decoder.blocks.2.attn.query.weight
# decoder.layers.2.self_attn.q_proj.bias -> decoder.blocks.2.attn.query.bias
# decoder.layers.2.self_attn.out_proj.weight -> decoder.blocks.2.attn.out.weight
# decoder.layers.2.self_attn.out_proj.bias -> decoder.blocks.2.attn.out.bias
# decoder.layers.2.self_attn_layer_norm.weight -> decoder.blocks.2.attn_ln.weight
# decoder.layers.2.self_attn_layer_norm.bias -> decoder.blocks.2.attn_ln.bias
# decoder.layers.2.encoder_attn.k_proj.weight -> decoder.blocks.2.cross_attn.key.weight
# decoder.layers.2.encoder_attn.v_proj.weight -> decoder.blocks.2.cross_attn.value.weight
# decoder.layers.2.encoder_attn.v_proj.bias -> decoder.blocks.2.cross_attn.value.bias
# decoder.layers.2.encoder_attn.q_proj.weight -> decoder.blocks.2.cross_attn.query.weight
# decoder.layers.2.encoder_attn.q_proj.bias -> decoder.blocks.2.cross_attn.query.bias
# decoder.layers.2.encoder_attn.out_proj.weight -> decoder.blocks.2.cross_attn.out.weight
# decoder.layers.2.encoder_attn.out_proj.bias -> decoder.blocks.2.cross_attn.out.bias
# decoder.layers.2.encoder_attn_layer_norm.weight -> decoder.blocks.2.cross_attn_ln.weight
# decoder.layers.2.encoder_attn_layer_norm.bias -> decoder.blocks.2.cross_attn_ln.bias
# decoder.layers.2.fc1.weight -> decoder.blocks.2.mlp.0.weight
# decoder.layers.2.fc1.bias -> decoder.blocks.2.mlp.0.bias
# decoder.layers.2.fc2.weight -> decoder.blocks.2.mlp.2.weight
# decoder.layers.2.fc2.bias -> decoder.blocks.2.mlp.2.bias
# decoder.layers.2.final_layer_norm.weight -> decoder.blocks.2.mlp_ln.weight
# decoder.layers.2.final_layer_norm.bias -> decoder.blocks.2.mlp_ln.bias
# decoder.layers.3.self_attn.k_proj.weight -> decoder.blocks.3.attn.key.weight
# decoder.layers.3.self_attn.v_proj.weight -> decoder.blocks.3.attn.value.weight
# decoder.layers.3.self_attn.v_proj.bias -> decoder.blocks.3.attn.value.bias
# decoder.layers.3.self_attn.q_proj.weight -> decoder.blocks.3.attn.query.weight
# decoder.layers.3.self_attn.q_proj.bias -> decoder.blocks.3.attn.query.bias
# decoder.layers.3.self_attn.out_proj.weight -> decoder.blocks.3.attn.out.weight
# decoder.layers.3.self_attn.out_proj.bias -> decoder.blocks.3.attn.out.bias
# decoder.layers.3.self_attn_layer_norm.weight -> decoder.blocks.3.attn_ln.weight
# decoder.layers.3.self_attn_layer_norm.bias -> decoder.blocks.3.attn_ln.bias
# decoder.layers.3.encoder_attn.k_proj.weight -> decoder.blocks.3.cross_attn.key.weight
# decoder.layers.3.encoder_attn.v_proj.weight -> decoder.blocks.3.cross_attn.value.weight
# decoder.layers.3.encoder_attn.v_proj.bias -> decoder.blocks.3.cross_attn.value.bias
# decoder.layers.3.encoder_attn.q_proj.weight -> decoder.blocks.3.cross_attn.query.weight
# decoder.layers.3.encoder_attn.q_proj.bias -> decoder.blocks.3.cross_attn.query.bias
# decoder.layers.3.encoder_attn.out_proj.weight -> decoder.blocks.3.cross_attn.out.weight
# decoder.layers.3.encoder_attn.out_proj.bias -> decoder.blocks.3.cross_attn.out.bias
# decoder.layers.3.encoder_attn_layer_norm.weight -> decoder.blocks.3.cross_attn_ln.weight
# decoder.layers.3.encoder_attn_layer_norm.bias -> decoder.blocks.3.cross_attn_ln.bias
# decoder.layers.3.fc1.weight -> decoder.blocks.3.mlp.0.weight
# decoder.layers.3.fc1.bias -> decoder.blocks.3.mlp.0.bias
# decoder.layers.3.fc2.weight -> decoder.blocks.3.mlp.2.weight
# decoder.layers.3.fc2.bias -> decoder.blocks.3.mlp.2.bias
# decoder.layers.3.final_layer_norm.weight -> decoder.blocks.3.mlp_ln.weight
# decoder.layers.3.final_layer_norm.bias -> decoder.blocks.3.mlp_ln.bias
# decoder.layers.4.self_attn.k_proj.weight -> decoder.blocks.4.attn.key.weight
# decoder.layers.4.self_attn.v_proj.weight -> decoder.blocks.4.attn.value.weight
# decoder.layers.4.self_attn.v_proj.bias -> decoder.blocks.4.attn.value.bias
# decoder.layers.4.self_attn.q_proj.weight -> decoder.blocks.4.attn.query.weight
# decoder.layers.4.self_attn.q_proj.bias -> decoder.blocks.4.attn.query.bias
# decoder.layers.4.self_attn.out_proj.weight -> decoder.blocks.4.attn.out.weight
# decoder.layers.4.self_attn.out_proj.bias -> decoder.blocks.4.attn.out.bias
# decoder.layers.4.self_attn_layer_norm.weight -> decoder.blocks.4.attn_ln.weight
# decoder.layers.4.self_attn_layer_norm.bias -> decoder.blocks.4.attn_ln.bias
# decoder.layers.4.encoder_attn.k_proj.weight -> decoder.blocks.4.cross_attn.key.weight
# decoder.layers.4.encoder_attn.v_proj.weight -> decoder.blocks.4.cross_attn.value.weight
# decoder.layers.4.encoder_attn.v_proj.bias -> decoder.blocks.4.cross_attn.value.bias
# decoder.layers.4.encoder_attn.q_proj.weight -> decoder.blocks.4.cross_attn.query.weight
# decoder.layers.4.encoder_attn.q_proj.bias -> decoder.blocks.4.cross_attn.query.bias
# decoder.layers.4.encoder_attn.out_proj.weight -> decoder.blocks.4.cross_attn.out.weight
# decoder.layers.4.encoder_attn.out_proj.bias -> decoder.blocks.4.cross_attn.out.bias
# decoder.layers.4.encoder_attn_layer_norm.weight -> decoder.blocks.4.cross_attn_ln.weight
# decoder.layers.4.encoder_attn_layer_norm.bias -> decoder.blocks.4.cross_attn_ln.bias
# decoder.layers.4.fc1.weight -> decoder.blocks.4.mlp.0.weight
# decoder.layers.4.fc1.bias -> decoder.blocks.4.mlp.0.bias
# decoder.layers.4.fc2.weight -> decoder.blocks.4.mlp.2.weight
# decoder.layers.4.fc2.bias -> decoder.blocks.4.mlp.2.bias
# decoder.layers.4.final_layer_norm.weight -> decoder.blocks.4.mlp_ln.weight
# decoder.layers.4.final_layer_norm.bias -> decoder.blocks.4.mlp_ln.bias
# decoder.layers.5.self_attn.k_proj.weight -> decoder.blocks.5.attn.key.weight
# decoder.layers.5.self_attn.v_proj.weight -> decoder.blocks.5.attn.value.weight
# decoder.layers.5.self_attn.v_proj.bias -> decoder.blocks.5.attn.value.bias
# decoder.layers.5.self_attn.q_proj.weight -> decoder.blocks.5.attn.query.weight
# decoder.layers.5.self_attn.q_proj.bias -> decoder.blocks.5.attn.query.bias
# decoder.layers.5.self_attn.out_proj.weight -> decoder.blocks.5.attn.out.weight
# decoder.layers.5.self_attn.out_proj.bias -> decoder.blocks.5.attn.out.bias
# decoder.layers.5.self_attn_layer_norm.weight -> decoder.blocks.5.attn_ln.weight
# decoder.layers.5.self_attn_layer_norm.bias -> decoder.blocks.5.attn_ln.bias
# decoder.layers.5.encoder_attn.k_proj.weight -> decoder.blocks.5.cross_attn.key.weight
# decoder.layers.5.encoder_attn.v_proj.weight -> decoder.blocks.5.cross_attn.value.weight
# decoder.layers.5.encoder_attn.v_proj.bias -> decoder.blocks.5.cross_attn.value.bias
# decoder.layers.5.encoder_attn.q_proj.weight -> decoder.blocks.5.cross_attn.query.weight
# decoder.layers.5.encoder_attn.q_proj.bias -> decoder.blocks.5.cross_attn.query.bias
# decoder.layers.5.encoder_attn.out_proj.weight -> decoder.blocks.5.cross_attn.out.weight
# decoder.layers.5.encoder_attn.out_proj.bias -> decoder.blocks.5.cross_attn.out.bias
# decoder.layers.5.encoder_attn_layer_norm.weight -> decoder.blocks.5.cross_attn_ln.weight
# decoder.layers.5.encoder_attn_layer_norm.bias -> decoder.blocks.5.cross_attn_ln.bias
# decoder.layers.5.fc1.weight -> decoder.blocks.5.mlp.0.weight
# decoder.layers.5.fc1.bias -> decoder.blocks.5.mlp.0.bias
# decoder.layers.5.fc2.weight -> decoder.blocks.5.mlp.2.weight
# decoder.layers.5.fc2.bias -> decoder.blocks.5.mlp.2.bias
# decoder.layers.5.final_layer_norm.weight -> decoder.blocks.5.mlp_ln.weight
# decoder.layers.5.final_layer_norm.bias -> decoder.blocks.5.mlp_ln.bias
# decoder.layers.6.self_attn.k_proj.weight -> decoder.blocks.6.attn.key.weight
# decoder.layers.6.self_attn.v_proj.weight -> decoder.blocks.6.attn.value.weight
# decoder.layers.6.self_attn.v_proj.bias -> decoder.blocks.6.attn.value.bias
# decoder.layers.6.self_attn.q_proj.weight -> decoder.blocks.6.attn.query.weight
# decoder.layers.6.self_attn.q_proj.bias -> decoder.blocks.6.attn.query.bias
# decoder.layers.6.self_attn.out_proj.weight -> decoder.blocks.6.attn.out.weight
# decoder.layers.6.self_attn.out_proj.bias -> decoder.blocks.6.attn.out.bias
# decoder.layers.6.self_attn_layer_norm.weight -> decoder.blocks.6.attn_ln.weight
# decoder.layers.6.self_attn_layer_norm.bias -> decoder.blocks.6.attn_ln.bias
# decoder.layers.6.encoder_attn.k_proj.weight -> decoder.blocks.6.cross_attn.key.weight
# decoder.layers.6.encoder_attn.v_proj.weight -> decoder.blocks.6.cross_attn.value.weight
# decoder.layers.6.encoder_attn.v_proj.bias -> decoder.blocks.6.cross_attn.value.bias
# decoder.layers.6.encoder_attn.q_proj.weight -> decoder.blocks.6.cross_attn.query.weight
# decoder.layers.6.encoder_attn.q_proj.bias -> decoder.blocks.6.cross_attn.query.bias
# decoder.layers.6.encoder_attn.out_proj.weight -> decoder.blocks.6.cross_attn.out.weight
# decoder.layers.6.encoder_attn.out_proj.bias -> decoder.blocks.6.cross_attn.out.bias
# decoder.layers.6.encoder_attn_layer_norm.weight -> decoder.blocks.6.cross_attn_ln.weight
# decoder.layers.6.encoder_attn_layer_norm.bias -> decoder.blocks.6.cross_attn_ln.bias
# decoder.layers.6.fc1.weight -> decoder.blocks.6.mlp.0.weight
# decoder.layers.6.fc1.bias -> decoder.blocks.6.mlp.0.bias
# decoder.layers.6.fc2.weight -> decoder.blocks.6.mlp.2.weight
# decoder.layers.6.fc2.bias -> decoder.blocks.6.mlp.2.bias
# decoder.layers.6.final_layer_norm.weight -> decoder.blocks.6.mlp_ln.weight
# decoder.layers.6.final_layer_norm.bias -> decoder.blocks.6.mlp_ln.bias
# decoder.layers.7.self_attn.k_proj.weight -> decoder.blocks.7.attn.key.weight
# decoder.layers.7.self_attn.v_proj.weight -> decoder.blocks.7.attn.value.weight
# decoder.layers.7.self_attn.v_proj.bias -> decoder.blocks.7.attn.value.bias
# decoder.layers.7.self_attn.q_proj.weight -> decoder.blocks.7.attn.query.weight
# decoder.layers.7.self_attn.q_proj.bias -> decoder.blocks.7.attn.query.bias
# decoder.layers.7.self_attn.out_proj.weight -> decoder.blocks.7.attn.out.weight
# decoder.layers.7.self_attn.out_proj.bias -> decoder.blocks.7.attn.out.bias
# decoder.layers.7.self_attn_layer_norm.weight -> decoder.blocks.7.attn_ln.weight
# decoder.layers.7.self_attn_layer_norm.bias -> decoder.blocks.7.attn_ln.bias
# decoder.layers.7.encoder_attn.k_proj.weight -> decoder.blocks.7.cross_attn.key.weight
# decoder.layers.7.encoder_attn.v_proj.weight -> decoder.blocks.7.cross_attn.value.weight
# decoder.layers.7.encoder_attn.v_proj.bias -> decoder.blocks.7.cross_attn.value.bias
# decoder.layers.7.encoder_attn.q_proj.weight -> decoder.blocks.7.cross_attn.query.weight
# decoder.layers.7.encoder_attn.q_proj.bias -> decoder.blocks.7.cross_attn.query.bias
# decoder.layers.7.encoder_attn.out_proj.weight -> decoder.blocks.7.cross_attn.out.weight
# decoder.layers.7.encoder_attn.out_proj.bias -> decoder.blocks.7.cross_attn.out.bias
# decoder.layers.7.encoder_attn_layer_norm.weight -> decoder.blocks.7.cross_attn_ln.weight
# decoder.layers.7.encoder_attn_layer_norm.bias -> decoder.blocks.7.cross_attn_ln.bias
# decoder.layers.7.fc1.weight -> decoder.blocks.7.mlp.0.weight
# decoder.layers.7.fc1.bias -> decoder.blocks.7.mlp.0.bias
# decoder.layers.7.fc2.weight -> decoder.blocks.7.mlp.2.weight
# decoder.layers.7.fc2.bias -> decoder.blocks.7.mlp.2.bias
# decoder.layers.7.final_layer_norm.weight -> decoder.blocks.7.mlp_ln.weight
# decoder.layers.7.final_layer_norm.bias -> decoder.blocks.7.mlp_ln.bias
# decoder.layers.8.self_attn.k_proj.weight -> decoder.blocks.8.attn.key.weight
# decoder.layers.8.self_attn.v_proj.weight -> decoder.blocks.8.attn.value.weight
# decoder.layers.8.self_attn.v_proj.bias -> decoder.blocks.8.attn.value.bias
# decoder.layers.8.self_attn.q_proj.weight -> decoder.blocks.8.attn.query.weight
# decoder.layers.8.self_attn.q_proj.bias -> decoder.blocks.8.attn.query.bias
# decoder.layers.8.self_attn.out_proj.weight -> decoder.blocks.8.attn.out.weight
# decoder.layers.8.self_attn.out_proj.bias -> decoder.blocks.8.attn.out.bias
# decoder.layers.8.self_attn_layer_norm.weight -> decoder.blocks.8.attn_ln.weight
# decoder.layers.8.self_attn_layer_norm.bias -> decoder.blocks.8.attn_ln.bias
# decoder.layers.8.encoder_attn.k_proj.weight -> decoder.blocks.8.cross_attn.key.weight
# decoder.layers.8.encoder_attn.v_proj.weight -> decoder.blocks.8.cross_attn.value.weight
# decoder.layers.8.encoder_attn.v_proj.bias -> decoder.blocks.8.cross_attn.value.bias
# decoder.layers.8.encoder_attn.q_proj.weight -> decoder.blocks.8.cross_attn.query.weight
# decoder.layers.8.encoder_attn.q_proj.bias -> decoder.blocks.8.cross_attn.query.bias
# decoder.layers.8.encoder_attn.out_proj.weight -> decoder.blocks.8.cross_attn.out.weight
# decoder.layers.8.encoder_attn.out_proj.bias -> decoder.blocks.8.cross_attn.out.bias
# decoder.layers.8.encoder_attn_layer_norm.weight -> decoder.blocks.8.cross_attn_ln.weight
# decoder.layers.8.encoder_attn_layer_norm.bias -> decoder.blocks.8.cross_attn_ln.bias
# decoder.layers.8.fc1.weight -> decoder.blocks.8.mlp.0.weight
# decoder.layers.8.fc1.bias -> decoder.blocks.8.mlp.0.bias
# decoder.layers.8.fc2.weight -> decoder.blocks.8.mlp.2.weight
# decoder.layers.8.fc2.bias -> decoder.blocks.8.mlp.2.bias
# decoder.layers.8.final_layer_norm.weight -> decoder.blocks.8.mlp_ln.weight
# decoder.layers.8.final_layer_norm.bias -> decoder.blocks.8.mlp_ln.bias
# decoder.layers.9.self_attn.k_proj.weight -> decoder.blocks.9.attn.key.weight
# decoder.layers.9.self_attn.v_proj.weight -> decoder.blocks.9.attn.value.weight
# decoder.layers.9.self_attn.v_proj.bias -> decoder.blocks.9.attn.value.bias
# decoder.layers.9.self_attn.q_proj.weight -> decoder.blocks.9.attn.query.weight
# decoder.layers.9.self_attn.q_proj.bias -> decoder.blocks.9.attn.query.bias
# decoder.layers.9.self_attn.out_proj.weight -> decoder.blocks.9.attn.out.weight
# decoder.layers.9.self_attn.out_proj.bias -> decoder.blocks.9.attn.out.bias
# decoder.layers.9.self_attn_layer_norm.weight -> decoder.blocks.9.attn_ln.weight
# decoder.layers.9.self_attn_layer_norm.bias -> decoder.blocks.9.attn_ln.bias
# decoder.layers.9.encoder_attn.k_proj.weight -> decoder.blocks.9.cross_attn.key.weight
# decoder.layers.9.encoder_attn.v_proj.weight -> decoder.blocks.9.cross_attn.value.weight
# decoder.layers.9.encoder_attn.v_proj.bias -> decoder.blocks.9.cross_attn.value.bias
# decoder.layers.9.encoder_attn.q_proj.weight -> decoder.blocks.9.cross_attn.query.weight
# decoder.layers.9.encoder_attn.q_proj.bias -> decoder.blocks.9.cross_attn.query.bias
# decoder.layers.9.encoder_attn.out_proj.weight -> decoder.blocks.9.cross_attn.out.weight
# decoder.layers.9.encoder_attn.out_proj.bias -> decoder.blocks.9.cross_attn.out.bias
# decoder.layers.9.encoder_attn_layer_norm.weight -> decoder.blocks.9.cross_attn_ln.weight
# decoder.layers.9.encoder_attn_layer_norm.bias -> decoder.blocks.9.cross_attn_ln.bias
# decoder.layers.9.fc1.weight -> decoder.blocks.9.mlp.0.weight
# decoder.layers.9.fc1.bias -> decoder.blocks.9.mlp.0.bias
# decoder.layers.9.fc2.weight -> decoder.blocks.9.mlp.2.weight
# decoder.layers.9.fc2.bias -> decoder.blocks.9.mlp.2.bias
# decoder.layers.9.final_layer_norm.weight -> decoder.blocks.9.mlp_ln.weight
# decoder.layers.9.final_layer_norm.bias -> decoder.blocks.9.mlp_ln.bias
# decoder.layers.10.self_attn.k_proj.weight -> decoder.blocks.10.attn.key.weight
# decoder.layers.10.self_attn.v_proj.weight -> decoder.blocks.10.attn.value.weight
# decoder.layers.10.self_attn.v_proj.bias -> decoder.blocks.10.attn.value.bias
# decoder.layers.10.self_attn.q_proj.weight -> decoder.blocks.10.attn.query.weight
# decoder.layers.10.self_attn.q_proj.bias -> decoder.blocks.10.attn.query.bias
# decoder.layers.10.self_attn.out_proj.weight -> decoder.blocks.10.attn.out.weight
# decoder.layers.10.self_attn.out_proj.bias -> decoder.blocks.10.attn.out.bias
# decoder.layers.10.self_attn_layer_norm.weight -> decoder.blocks.10.attn_ln.weight
# decoder.layers.10.self_attn_layer_norm.bias -> decoder.blocks.10.attn_ln.bias
# decoder.layers.10.encoder_attn.k_proj.weight -> decoder.blocks.10.cross_attn.key.weight
# decoder.layers.10.encoder_attn.v_proj.weight -> decoder.blocks.10.cross_attn.value.weight
# decoder.layers.10.encoder_attn.v_proj.bias -> decoder.blocks.10.cross_attn.value.bias
# decoder.layers.10.encoder_attn.q_proj.weight -> decoder.blocks.10.cross_attn.query.weight
# decoder.layers.10.encoder_attn.q_proj.bias -> decoder.blocks.10.cross_attn.query.bias
# decoder.layers.10.encoder_attn.out_proj.weight -> decoder.blocks.10.cross_attn.out.weight
# decoder.layers.10.encoder_attn.out_proj.bias -> decoder.blocks.10.cross_attn.out.bias
# decoder.layers.10.encoder_attn_layer_norm.weight -> decoder.blocks.10.cross_attn_ln.weight
# decoder.layers.10.encoder_attn_layer_norm.bias -> decoder.blocks.10.cross_attn_ln.bias
# decoder.layers.10.fc1.weight -> decoder.blocks.10.mlp.0.weight
# decoder.layers.10.fc1.bias -> decoder.blocks.10.mlp.0.bias
# decoder.layers.10.fc2.weight -> decoder.blocks.10.mlp.2.weight
# decoder.layers.10.fc2.bias -> decoder.blocks.10.mlp.2.bias
# decoder.layers.10.final_layer_norm.weight -> decoder.blocks.10.mlp_ln.weight
# decoder.layers.10.final_layer_norm.bias -> decoder.blocks.10.mlp_ln.bias
# decoder.layers.11.self_attn.k_proj.weight -> decoder.blocks.11.attn.key.weight
# decoder.layers.11.self_attn.v_proj.weight -> decoder.blocks.11.attn.value.weight
# decoder.layers.11.self_attn.v_proj.bias -> decoder.blocks.11.attn.value.bias
# decoder.layers.11.self_attn.q_proj.weight -> decoder.blocks.11.attn.query.weight
# decoder.layers.11.self_attn.q_proj.bias -> decoder.blocks.11.attn.query.bias
# decoder.layers.11.self_attn.out_proj.weight -> decoder.blocks.11.attn.out.weight
# decoder.layers.11.self_attn.out_proj.bias -> decoder.blocks.11.attn.out.bias
# decoder.layers.11.self_attn_layer_norm.weight -> decoder.blocks.11.attn_ln.weight
# decoder.layers.11.self_attn_layer_norm.bias -> decoder.blocks.11.attn_ln.bias
# decoder.layers.11.encoder_attn.k_proj.weight -> decoder.blocks.11.cross_attn.key.weight
# decoder.layers.11.encoder_attn.v_proj.weight -> decoder.blocks.11.cross_attn.value.weight
# decoder.layers.11.encoder_attn.v_proj.bias -> decoder.blocks.11.cross_attn.value.bias
# decoder.layers.11.encoder_attn.q_proj.weight -> decoder.blocks.11.cross_attn.query.weight
# decoder.layers.11.encoder_attn.q_proj.bias -> decoder.blocks.11.cross_attn.query.bias
# decoder.layers.11.encoder_attn.out_proj.weight -> decoder.blocks.11.cross_attn.out.weight
# decoder.layers.11.encoder_attn.out_proj.bias -> decoder.blocks.11.cross_attn.out.bias
# decoder.layers.11.encoder_attn_layer_norm.weight -> decoder.blocks.11.cross_attn_ln.weight
# decoder.layers.11.encoder_attn_layer_norm.bias -> decoder.blocks.11.cross_attn_ln.bias
# decoder.layers.11.fc1.weight -> decoder.blocks.11.mlp.0.weight
# decoder.layers.11.fc1.bias -> decoder.blocks.11.mlp.0.bias
# decoder.layers.11.fc2.weight -> decoder.blocks.11.mlp.2.weight
# decoder.layers.11.fc2.bias -> decoder.blocks.11.mlp.2.bias
# decoder.layers.11.final_layer_norm.weight -> decoder.blocks.11.mlp_ln.weight
# decoder.layers.11.final_layer_norm.bias -> decoder.blocks.11.mlp_ln.bias
# decoder.layer_norm.weight -> decoder.ln.weight
# decoder.layer_norm.bias -> decoder.ln.bias

# %% [markdown]
# ## Closing Remarks

# %% [markdown]
# In this blog, we covered a step-by-step guide on fine-tuning Whisper for multilingual ASR
# using 🤗 Datasets, Transformers and the Hugging Face Hub. For more details on the Whisper model, the Common Voice dataset and the theory behind fine-tuning, refere to the accompanying [blog post](https://huggingface.co/blog/fine-tune-whisper). If you're interested in fine-tuning other
# Transformers models, both for English and multilingual ASR, be sure to check out the
# examples scripts at [examples/pytorch/speech-recognition](https://github.com/huggingface/transformers/tree/main/examples/pytorch/speech-recognition).
